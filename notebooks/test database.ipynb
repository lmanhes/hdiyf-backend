# %%
import os, sys
sys.path.append('..')
import pandas as pd

import sqlalchemy
from app.database.models import News
from app.database import SessionLocal, engine, Base

# %%
Base.metadata.
# Out:
# MetaData(bind=None)

# %%
db = SessionLocal()
Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)

# %%
db.query(News).all()
# Out:
# []

# %%
df = pd.read_csv("../data/clean_fake_news_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
for i, row in df.iterrows():
    if i % 100 == 0:
        print(f"\n{i+1} / {len(df)} news processed\n")
    news = News(title=row.title,
               text=row.text,
               subject=row.subject,
               label=row.label)
    db.add(news)
    db.commit()
# Out:
# 1 / 44898 news processed
#
#
# 101 / 44898 news processed
#
#
# 201 / 44898 news processed
#
#
# 301 / 44898 news processed
#
#
# 401 / 44898 news processed
#
#
# 501 / 44898 news processed
#
#
# 601 / 44898 news processed
#
#
# 701 / 44898 news processed
#
#
# 801 / 44898 news processed
#
#
# 901 / 44898 news processed
#
#
# 1001 / 44898 news processed
#
#
# 1101 / 44898 news processed
#
#
# 1201 / 44898 news processed
#
#
# 1301 / 44898 news processed
#
#
# 1401 / 44898 news processed
#
#
# 1501 / 44898 news processed
#
#
# 1601 / 44898 news processed
#
#
# 1701 / 44898 news processed
#
#
# 1801 / 44898 news processed
#
#
# 1901 / 44898 news processed
#
#
# 2001 / 44898 news processed
#
#
# 2101 / 44898 news processed
#
#
# 2201 / 44898 news processed
#
#
# 2301 / 44898 news processed
#
#
# 2401 / 44898 news processed
#
#
# 2501 / 44898 news processed
#
#
# 2601 / 44898 news processed
#
#
# 2701 / 44898 news processed
#
#
# 2801 / 44898 news processed
#
#
# 2901 / 44898 news processed
#
#
# 3001 / 44898 news processed
#
#
# 3101 / 44898 news processed
#
#
# 3201 / 44898 news processed
#
#
# 3301 / 44898 news processed
#
#
# 3401 / 44898 news processed
#
#
# 3501 / 44898 news processed
#
#
# 3601 / 44898 news processed
#
#
# 3701 / 44898 news processed
#
#
# 3801 / 44898 news processed
#
#
# 3901 / 44898 news processed
#
#
# 4001 / 44898 news processed
#
#
# 4101 / 44898 news processed
#
#
# 4201 / 44898 news processed
#
#
# 4301 / 44898 news processed
#
#
# 4401 / 44898 news processed
#
#
# 4501 / 44898 news processed
#
#
# 4601 / 44898 news processed
#
#
# 4701 / 44898 news processed
#
#
# 4801 / 44898 news processed
#
#
# 4901 / 44898 news processed
#
#
# 5001 / 44898 news processed
#
#
# 5101 / 44898 news processed
#
#
# 5201 / 44898 news processed
#
#
# 5301 / 44898 news processed
#
#
# 5401 / 44898 news processed
#
#
# 5501 / 44898 news processed
#
#
# 5601 / 44898 news processed
#
#
# 5701 / 44898 news processed
#
#
# 5801 / 44898 news processed
#
#
# 5901 / 44898 news processed
#
#
# 6001 / 44898 news processed
#
#
# 6101 / 44898 news processed
#
#
# 6201 / 44898 news processed
#
#
# 6301 / 44898 news processed
#
#
# 6401 / 44898 news processed
#
#
# 6501 / 44898 news processed
#
#
# 6601 / 44898 news processed
#
#
# 6701 / 44898 news processed
#
#
# 6801 / 44898 news processed
#
#
# 6901 / 44898 news processed
#
#
# 7001 / 44898 news processed
#
#
# 7101 / 44898 news processed
#
#
# 7201 / 44898 news processed
#
#
# 7301 / 44898 news processed
#
#
# 7401 / 44898 news processed
#
#
# 7501 / 44898 news processed
#
#
# 7601 / 44898 news processed
#
#
# 7701 / 44898 news processed
#
#
# 7801 / 44898 news processed
#
#
# 7901 / 44898 news processed
#
#
# 8001 / 44898 news processed
#
#
# 8101 / 44898 news processed
#
#
# 8201 / 44898 news processed
#
#
# 8301 / 44898 news processed
#
#
# 8401 / 44898 news processed
#
#
# 8501 / 44898 news processed
#
#
# 8601 / 44898 news processed
#
#
# 8701 / 44898 news processed
#
#
# 8801 / 44898 news processed
#
#
# 8901 / 44898 news processed
#
#
# 9001 / 44898 news processed
#
#
# 9101 / 44898 news processed
#
#
# 9201 / 44898 news processed
#
#
# 9301 / 44898 news processed
#
#
# 9401 / 44898 news processed
#
#
# 9501 / 44898 news processed
#
#
# 9601 / 44898 news processed
#
#
# 9701 / 44898 news processed
#
#
# 9801 / 44898 news processed
#
#
# 9901 / 44898 news processed
#
#
# 10001 / 44898 news processed
#
#
# 10101 / 44898 news processed
#
#
# 10201 / 44898 news processed
#
#
# 10301 / 44898 news processed
#
#
# 10401 / 44898 news processed
#
#
# 10501 / 44898 news processed
#
#
# 10601 / 44898 news processed
#
#
# 10701 / 44898 news processed
#
#
# 10801 / 44898 news processed
#
#
# 10901 / 44898 news processed
#
#
# 11001 / 44898 news processed
#
#
# 11101 / 44898 news processed
#
#
# 11201 / 44898 news processed
#
#
# 11301 / 44898 news processed
#
#
# 11401 / 44898 news processed
#
#
# 11501 / 44898 news processed
#
#
# 11601 / 44898 news processed
#
#
# 11701 / 44898 news processed
#
#
# 11801 / 44898 news processed
#
#
# 11901 / 44898 news processed
#
#
# 12001 / 44898 news processed
#
#
# 12101 / 44898 news processed
#
#
# 12201 / 44898 news processed
#
#
# 12301 / 44898 news processed
#
#
# 12401 / 44898 news processed
#
#
# 12501 / 44898 news processed
#
#
# 12601 / 44898 news processed
#
#
# 12701 / 44898 news processed
#
#
# 12801 / 44898 news processed
#
#
# 12901 / 44898 news processed
#
#
# 13001 / 44898 news processed
#
#
# 13101 / 44898 news processed
#
#
# 13201 / 44898 news processed
#
#
# 13301 / 44898 news processed
#
#
# 13401 / 44898 news processed
#
#
# 13501 / 44898 news processed
#
#
# 13601 / 44898 news processed
#
#
# 13701 / 44898 news processed
#
#
# 13801 / 44898 news processed
#
#
# 13901 / 44898 news processed
#
#
# 14001 / 44898 news processed
#
#
# 14101 / 44898 news processed
#
#
# 14201 / 44898 news processed
#
#
# 14301 / 44898 news processed
#
#
# 14401 / 44898 news processed
#
#
# 14501 / 44898 news processed
#
#
# 14601 / 44898 news processed
#
#
# 14701 / 44898 news processed
#
#
# 14801 / 44898 news processed
#
#
# 14901 / 44898 news processed
#
#
# 15001 / 44898 news processed
#
#
# 15101 / 44898 news processed
#
#
# 15201 / 44898 news processed
#
#
# 15301 / 44898 news processed
#
#
# 15401 / 44898 news processed
#
#
# 15501 / 44898 news processed
#
#
# 15601 / 44898 news processed
#
#
# 15701 / 44898 news processed
#
#
# 15801 / 44898 news processed
#
#
# 15901 / 44898 news processed
#
#
# 16001 / 44898 news processed
#
#
# 16101 / 44898 news processed
#
#
# 16201 / 44898 news processed
#
#
# 16301 / 44898 news processed
#
#
# 16401 / 44898 news processed
#
#
# 16501 / 44898 news processed
#
#
# 16601 / 44898 news processed
#
#
# 16701 / 44898 news processed
#
#
# 16801 / 44898 news processed
#
#
# 16901 / 44898 news processed
#
#
# 17001 / 44898 news processed
#
#
# 17101 / 44898 news processed
#
#
# 17201 / 44898 news processed
#
#
# 17301 / 44898 news processed
#
#
# 17401 / 44898 news processed
#
#
# 17501 / 44898 news processed
#
#
# 17601 / 44898 news processed
#
#
# 17701 / 44898 news processed
#
#
# 17801 / 44898 news processed
#
#
# 17901 / 44898 news processed
#
#
# 18001 / 44898 news processed
#
#
# 18101 / 44898 news processed
#
#
# 18201 / 44898 news processed
#
#
# 18301 / 44898 news processed
#
#
# 18401 / 44898 news processed
#
#
# 18501 / 44898 news processed
#
#
# 18601 / 44898 news processed
#
#
# 18701 / 44898 news processed
#
#
# 18801 / 44898 news processed
#
#
# 18901 / 44898 news processed
#
#
# 19001 / 44898 news processed
#
#
# 19101 / 44898 news processed
#
#
# 19201 / 44898 news processed
#
#
# 19301 / 44898 news processed
#
#
# 19401 / 44898 news processed
#
#
# 19501 / 44898 news processed
#
#
# 19601 / 44898 news processed
#
#
# 19701 / 44898 news processed
#
#
# 19801 / 44898 news processed
#
#
# 19901 / 44898 news processed
#
#
# 20001 / 44898 news processed
#
#
# 20101 / 44898 news processed
#
#
# 20201 / 44898 news processed
#
#
# 20301 / 44898 news processed
#
#
# 20401 / 44898 news processed
#
#
# 20501 / 44898 news processed
#
#
# 20601 / 44898 news processed
#
#
# 20701 / 44898 news processed
#
#
# 20801 / 44898 news processed
#
#
# 20901 / 44898 news processed
#
#
# 21001 / 44898 news processed
#
#
# 21101 / 44898 news processed
#
#
# 21201 / 44898 news processed
#
#
# 21301 / 44898 news processed
#
#
# 21401 / 44898 news processed
#
#
# 21501 / 44898 news processed
#
#
# 21601 / 44898 news processed
#
#
# 21701 / 44898 news processed
#
#
# 21801 / 44898 news processed
#
#
# 21901 / 44898 news processed
#
#
# 22001 / 44898 news processed
#
#
# 22101 / 44898 news processed
#
#
# 22201 / 44898 news processed
#
#
# 22301 / 44898 news processed
#
#
# 22401 / 44898 news processed
#
#
# 22501 / 44898 news processed
#
#
# 22601 / 44898 news processed
#
#
# 22701 / 44898 news processed
#
#
# 22801 / 44898 news processed
#
#
# 22901 / 44898 news processed
#
#
# 23001 / 44898 news processed
#
#
# 23101 / 44898 news processed
#
#
# 23201 / 44898 news processed
#
#
# 23301 / 44898 news processed
#
#
# 23401 / 44898 news processed
#
#
# 23501 / 44898 news processed
#
#
# 23601 / 44898 news processed
#
#
# 23701 / 44898 news processed
#
#
# 23801 / 44898 news processed
#
#
# 23901 / 44898 news processed
#
#
# 24001 / 44898 news processed
#
#
# 24101 / 44898 news processed
#
#
# 24201 / 44898 news processed
#
#
# 24301 / 44898 news processed
#
#
# 24401 / 44898 news processed
#
#
# 24501 / 44898 news processed
#
#
# 24601 / 44898 news processed
#
#
# 24701 / 44898 news processed
#
#
# 24801 / 44898 news processed
#
#
# 24901 / 44898 news processed
#
#
# 25001 / 44898 news processed
#
#
# 25101 / 44898 news processed
#
#
# 25201 / 44898 news processed
#
#
# 25301 / 44898 news processed
#
#
# 25401 / 44898 news processed
#
#
# 25501 / 44898 news processed
#
#
# 25601 / 44898 news processed
#
#
# 25701 / 44898 news processed
#
#
# 25801 / 44898 news processed
#
#
# 25901 / 44898 news processed
#
#
# 26001 / 44898 news processed
#
#
# 26101 / 44898 news processed
#
#
# 26201 / 44898 news processed
#
#
# 26301 / 44898 news processed
#
#
# 26401 / 44898 news processed
#
#
# 26501 / 44898 news processed
#
#
# 26601 / 44898 news processed
#
#
# 26701 / 44898 news processed
# 26801 / 44898 news processed
#
#
# 26901 / 44898 news processed
#
#
# 27001 / 44898 news processed
#
#
# 27101 / 44898 news processed
#
#
# 27201 / 44898 news processed
#
#
# 27301 / 44898 news processed
#
#
# 27401 / 44898 news processed
#
#
# 27501 / 44898 news processed
#
#
# 27601 / 44898 news processed
#
#
# 27701 / 44898 news processed
#
#
# 27801 / 44898 news processed
#
#
# 27901 / 44898 news processed
#
#
# 28001 / 44898 news processed
#
#
# 28101 / 44898 news processed
#
#
# 28201 / 44898 news processed
#
#
# 28301 / 44898 news processed
#
#
# 28401 / 44898 news processed
#
#
# 28501 / 44898 news processed
#
#
# 28601 / 44898 news processed
#
#
# 28701 / 44898 news processed
#
#
# 28801 / 44898 news processed
#
#
# 28901 / 44898 news processed
#
#
# 29001 / 44898 news processed
#
#
# 29101 / 44898 news processed
#
#
# 29201 / 44898 news processed
#
#
# 29301 / 44898 news processed
#
#
# 29401 / 44898 news processed
#
#
# 29501 / 44898 news processed
#
#
# 29601 / 44898 news processed
#
#
# 29701 / 44898 news processed
#
#
# 29801 / 44898 news processed
#
#
# 29901 / 44898 news processed
#
#
# 30001 / 44898 news processed
#
#
# 30101 / 44898 news processed
#
#
# 30201 / 44898 news processed
#
#
# 30301 / 44898 news processed
#
#
# 30401 / 44898 news processed
#
#
# 30501 / 44898 news processed
#
#
# 30601 / 44898 news processed
#
#
# 30701 / 44898 news processed
#
#
# 30801 / 44898 news processed
#
#
# 30901 / 44898 news processed
#
#
# 31001 / 44898 news processed
#
#
# 31101 / 44898 news processed
#
#
# 31201 / 44898 news processed
#
#
# 31301 / 44898 news processed
#
#
# 31401 / 44898 news processed
#
#
# 31501 / 44898 news processed
#
#
# 31601 / 44898 news processed
#
#
# 31701 / 44898 news processed
#
#
# 31801 / 44898 news processed
#
#
# 31901 / 44898 news processed
#
#
# 32001 / 44898 news processed
#
#
# 32101 / 44898 news processed
#
#
# 32201 / 44898 news processed
#
#
# 32301 / 44898 news processed
#
#
# 32401 / 44898 news processed
#
#
# 32501 / 44898 news processed
#
#
# 32601 / 44898 news processed
#
#
# 32701 / 44898 news processed
#
#
# 32801 / 44898 news processed
#
#
# 32901 / 44898 news processed
#
#
# 33001 / 44898 news processed
#
#
# 33101 / 44898 news processed
#
#
# 33201 / 44898 news processed
#
#
# 33301 / 44898 news processed
#
#
# 33401 / 44898 news processed
#
#
# 33501 / 44898 news processed
#
#
# 33601 / 44898 news processed
#
#
# 33701 / 44898 news processed
#
#
# 33801 / 44898 news processed
#
#
# 33901 / 44898 news processed
#
#
# 34001 / 44898 news processed
#
#
# 34101 / 44898 news processed
#
#
# 34201 / 44898 news processed
#
#
# 34301 / 44898 news processed
#
#
# 34401 / 44898 news processed
#
#
# 34501 / 44898 news processed
#
#
# 34601 / 44898 news processed
#
#
# 34701 / 44898 news processed
#
#
# 34801 / 44898 news processed
#
#
# 34901 / 44898 news processed
#
#
# 35001 / 44898 news processed
#
#
# 35101 / 44898 news processed
#
#
# 35201 / 44898 news processed
#
#
# 35301 / 44898 news processed
#
#
# 35401 / 44898 news processed
#
#
# 35501 / 44898 news processed
#
#
# 35601 / 44898 news processed
#
#
# 35701 / 44898 news processed
#
#
# 35801 / 44898 news processed
#
#
# 35901 / 44898 news processed
#
#
# 36001 / 44898 news processed
#
#
# 36101 / 44898 news processed
#
#
# 36201 / 44898 news processed
#
#
# 36301 / 44898 news processed
#
#
# 36401 / 44898 news processed
#
#
# 36501 / 44898 news processed
#
#
# 36601 / 44898 news processed
#
#
# 36701 / 44898 news processed
#
#
# 36801 / 44898 news processed
#
#
# 36901 / 44898 news processed
#
#
# 37001 / 44898 news processed
#
#
# 37101 / 44898 news processed
#
#
# 37201 / 44898 news processed
#
#
# 37301 / 44898 news processed
#
#
# 37401 / 44898 news processed
#
#
# 37501 / 44898 news processed
#
#
# 37601 / 44898 news processed
#
#
# 37701 / 44898 news processed
#
#
# 37801 / 44898 news processed
#
#
# 37901 / 44898 news processed
#
#
# 38001 / 44898 news processed
#
#
# 38101 / 44898 news processed
#
#
# 38201 / 44898 news processed
#
#
# 38301 / 44898 news processed
#
#
# 38401 / 44898 news processed
#
#
# 38501 / 44898 news processed
#
#
# 38601 / 44898 news processed
#
#
# 38701 / 44898 news processed
#
#
# 38801 / 44898 news processed
#
#
# 38901 / 44898 news processed
#
#
# 39001 / 44898 news processed
#
#
# 39101 / 44898 news processed
#
#
# 39201 / 44898 news processed
#
#
# 39301 / 44898 news processed
#
#
# 39401 / 44898 news processed
#
#
# 39501 / 44898 news processed
#
#
# 39601 / 44898 news processed
#
#
# 39701 / 44898 news processed
#
#
# 39801 / 44898 news processed
#
#
# 39901 / 44898 news processed
#
#
# 40001 / 44898 news processed
#
#
# 40101 / 44898 news processed
#
#
# 40201 / 44898 news processed
#
#
# 40301 / 44898 news processed
#
#
# 40401 / 44898 news processed
#
#
# 40501 / 44898 news processed
#
#
# 40601 / 44898 news processed
#
#
# 40701 / 44898 news processed
#
#
# 40801 / 44898 news processed
#
#
# 40901 / 44898 news processed
#
#
# 41001 / 44898 news processed
#
#
# 41101 / 44898 news processed
#
#
# 41201 / 44898 news processed
#
#
# 41301 / 44898 news processed
#
#
# 41401 / 44898 news processed
#
#
# 41501 / 44898 news processed
#
#
# 41601 / 44898 news processed
#
#
# 41701 / 44898 news processed
#
#
# 41801 / 44898 news processed
#
#
# 41901 / 44898 news processed
#
#
# 42001 / 44898 news processed
#
#
# 42101 / 44898 news processed
#
#
# 42201 / 44898 news processed
#
#
# 42301 / 44898 news processed
#
#
# 42401 / 44898 news processed
#
#
# 42501 / 44898 news processed
#
#
# 42601 / 44898 news processed
#
#
# 42701 / 44898 news processed
#
#
# 42801 / 44898 news processed
#
#
# 42901 / 44898 news processed
#
#
# 43001 / 44898 news processed
#
#
# 43101 / 44898 news processed
#
#
# 43201 / 44898 news processed
#
#
# 43301 / 44898 news processed
#
#
# 43401 / 44898 news processed
#
#
# 43501 / 44898 news processed
#
#
# 43601 / 44898 news processed
#
#
# 43701 / 44898 news processed
#
#
# 43801 / 44898 news processed
#
#
# 43901 / 44898 news processed
#
#
# 44001 / 44898 news processed
#
#
# 44101 / 44898 news processed
#
#
# 44201 / 44898 news processed
#
#
# 44301 / 44898 news processed
#
#
# 44401 / 44898 news processed
#
#
# 44501 / 44898 news processed
#
#
# 44601 / 44898 news processed
#
#
# 44701 / 44898 news processed
#
#
# 44801 / 44898 news processed

# %%
db.query(News).order_by(sqlalchemy.func.random())[0].text
# Out:
# ' Jodie Foster gives a dose of common sense to set the record straight on the phony war on women being pushed by the left: I don t think there is a big plot to keep women down Jodie Foster said she s tired of people oversimplifying the issue of gender equality in Hollywood, declaring that there isn t some major plot in the industry  to keep women down. The 53-year-old  Money Monster  director made the comments Wednesday during a panel at the Tribeca Film Festival with fellow director Julie Taymor, Variety reported.Ms. Foster said,  I feel like the issue is way more complicated than saying,  Why aren t women making big mainstream franchises? There are so many reasons,  she continued.  Some of them are about our psychology, some of them are about the financial world, some of them are about the global economy. There are so many answers to that go back hundreds of years. It would be nice to be able to have a more complex conversation and to be able to look at it more than just a quota or numbers. I don t think there is a big plot to keep women down,  she added.  It is neglect really, and a lot of people that weren t thinking about it, and a lot of female executives who have risen to the top, who have not really made a dent of bringing many women into the mainstream world. Money Monster,  Ms. Foster s fourth feature film which premieres next month at the Cannes Film Festival, tells the story of a failed investor who holds a television commentator hostage on live TV, Variety reported. Though it comes at a time when Wall Street is at the center of debate in the Democratic presidential race, Ms. Foster insisted the film isn t meant to be political. For me really it is a character film,  she told the magazine.  The backdrop of technology is really interesting to me.   Technology is making us closer and we have this virtual intimacy that sometimes feels closer than real intimacy. Via: WT '
